# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#without nested loop
li = list(range(1,6)) #1,2,3,4,5

for i in li:
    if i == li[(len(li)-1)]:
        print("*"*(i-3),end="")
        print("  ",end="")
        print("*")
    else:
        print("*"*i)
for i in li[-2::-1]:
    print("*"*i)
    
#Jordan Flag Triangle <3
# Out:
# *
# **
# ***
# ****
# **  *
# ****
# ***
# **
# *

# %%
#using nested loop

li = list(range(1,6)) #1,2,3,4,5
for i in li:
    for j in range(i):
        print("*",end="")
    print()
for i in li[-2::-1]: #to exclude the last item "5" we start from -2
    for j in range(i):
        print("*",end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(" ",end="")         #first part
print("*"*3,end="") 
print(" ")
    
for j in range(2):       #second part
    print("*",end="")
    print("   ",end="")
    print("*")
    
print("*"*5)             #third part
    
for j in range(2):       #fourth part
    print("*",end="")
    print("   ",end="")
    print("*")
# Out:
#  ***
# *   *
# *   *
# *****
# *   *
# *   *

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 0
summation = 0
numbers = 0
while True:
    n = int(input())
    if n == 1:
        break
    summation += n
    numbers += 1
if numbers !=0 :
    print("Summation = "+str(summation)+"\nAverage = "+str(summation/numbers))
# Out:
# 5
# 1
# Summation = 5
# Average = 5.0

# %% [markdown]
# ### extra Question with its solution

# %%
#the summation and the average of a number's digits
#I solve the previous question as we have to calculate the sum of one number's digits.. so i kept it here as a new one.

n = int(input())
sum = 0
loops = 0
while n>0:
    digit = n%10
    n //= 10
    sum += digit
    loops += 1
print("Sum = "+str(sum)+"\nAvg = "+str(sum/loops))
# Out:
# 12345
# Sum = 15
# Avg = 3.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
password = input()

more_than_min = len(password) >= 6
less_than_max = len(password) <= 16

has_digit = False
has_letter = False
has_special_char = False

for char in password:
    if char.isdigit():
        has_digit = True
    elif char.isalpha():
        has_letter = True
    elif char in ["$","#","@"]:
        has_special_char = True
    if has_digit and has_letter and has_special_char:
        break

if more_than_min and less_than_max and has_digit and has_letter and has_special_char:
    print("Valid Password: "+str(password))
else:
    print("Non Valid Password: "+str(password))
    

# let it until i study the whole material
# Out:
# fjoe9ke33/.,l;
# Non Valid Password: fjoe9ke33/.,l;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
String = input()
count = 0
for i in String:
    if i.isdigit() or i.isalpha():
        count += 1
print(count)
# Out:
# fnke3/3,30
# 8

# %%
#using the ASCII code
String = input()
count = 0
for i in String:
    if (ord(i) >= 65 and ord(i) <= 90) or (ord(i) >= 97 and ord(i) <= 122) or (ord(i) >= 48 and ord(i) <= 57):
        count += 1
print(count)
# print(ord("A"),ord("Z"),ord("a"),ord("z"),ord("0"),ord("1"),ord("9"))
# Out:
# hfune
# 5
